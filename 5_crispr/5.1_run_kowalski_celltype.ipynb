# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '7'
import driver_genes as dg
dg.set_verbosity(False)
from driver_genes.pipelines import Pipeline

# %% [markdown]
# ## fit model

# %%
pp = Pipeline(config_path='config_kolwaski_hek293ft.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
os.makedirs(os.path.join(pp.args.trainer.output_dir, 'anndata'), exist_ok=True)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.702    Total estimated model params size (MB)
# 65        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ### train on k562

# %%
pp = Pipeline(config_path='config_kolwaski_k562.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
os.makedirs(os.path.join(pp.args.trainer.output_dir, 'anndata'), exist_ok=True)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.965    Total estimated model params size (MB)
# 67        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ## fitting noisy data

# %%
import numpy as np
import torch
import pandas as pd

# %% [markdown]
# train on hek293ft noisy data

# %%
pp = Pipeline(config_path='config_kolwaski_hek293ft_noisy.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=False)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.702    Total estimated model params size (MB)
# 65        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %%
# pp = Pipeline(config_path='../results/kowalski/hek293ft_noisy-seed42/config.yaml', fitted=True)
pp.args.dataset.condition_key = 'perturbation_true'
pp.reload_data()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=False)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics_true.csv'), index=False)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}_true.h5ad'
    ))
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %%
pp = Pipeline(config_path='../results/kowalski/hek293ft_noisy-seed42/config.yaml', fitted=True)
pp.args.dataset.condition_key = 'perturbation_true'
pp.reload_data()
_, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
# metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics_true.csv'), index=False)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}_true_agg.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# train on k562 noisy data

# %%
pp = Pipeline(config_path='config_kolwaski_k562_noisy.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=False)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.965    Total estimated model params size (MB)
# 67        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %%
# pp = Pipeline(config_path='../results/kowalski/k562_noisy-seed42/config.yaml', fitted=True)
pp.args.dataset.condition_key = 'perturbation_true'
pp.reload_data()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=False)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics_true.csv'), index=False)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}_true.h5ad'
    ))
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ## train a model on the training set and test on the test set

# %%
pp = Pipeline(config_path='config_kolwaski_hek293ft_r2.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
os.makedirs(os.path.join(pp.args.trainer.output_dir, 'anndata'), exist_ok=True)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.702    Total estimated model params size (MB)
# 65        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %%
metrics_df
# Out:
#                       prefix  ACC@Top1  ACC@Top5  Coverage       MRR  \
# 0   preprocessed_HEK293FT_R1  0.639998  0.855771  3.606293  0.737457
# 1   preprocessed_HEK293FT_R2  0.662003  0.879656  2.978434  0.756623
# 2          preprocessed_K562  0.297670  0.559725  7.903047  0.426805
# 3                          a  0.533427  0.765125  4.825562  0.640397
# 4   preprocessed_HEK293FT_R1  0.649951  0.855394  3.663316  0.742585
# 5   preprocessed_HEK293FT_R2  0.670001  0.876234  2.933604  0.761568
# 6          preprocessed_K562  0.302061  0.567069  7.844088  0.432369
# 7                          a  0.540333  0.765899  4.813870  0.645222
# 8   preprocessed_HEK293FT_R1  0.647382  0.850346  3.619348  0.739899
# 9   preprocessed_HEK293FT_R2  0.652377  0.872609  3.004908  0.749837
# 10         preprocessed_K562  0.296460  0.560608  7.955394  0.429523
# 11                         a  0.532015  0.761491  4.856507  0.639822
# 12  preprocessed_HEK293FT_R1  0.655492  0.859383  3.441529  0.748817
# 13  preprocessed_HEK293FT_R2  0.649702  0.867709  3.040830  0.746628
# 14         preprocessed_K562  0.290016  0.554450  8.000490  0.421700
# 15                         a  0.532112  0.760486  4.822203  0.639304
# 16  preprocessed_HEK293FT_R1  0.647224  0.854905  3.606846  0.740338
# 17  preprocessed_HEK293FT_R2  0.666490  0.876493  2.936420  0.759640
# 18         preprocessed_K562  0.314708  0.579232  7.673743  0.443606
# 19                         a  0.542615  0.769851  4.745065  0.647645
#
#     RankingLoss    RelPos  label#AUPRC  label#AUROC  label#F1  ...  \
# 0      0.078979  0.921021     0.724092     0.951632  0.609654  ...
# 1      0.059953  0.940048     0.726640     0.960816  0.615506  ...
# 2      0.209183  0.790817     0.347998     0.844944  0.213162  ...
# 3      0.115926  0.884074     0.599147     0.919166  0.479648  ...
# 4      0.080707  0.919293     0.728734     0.950268  0.610278  ...
# 5      0.058594  0.941406     0.726955     0.962022  0.617693  ...
# 6      0.207397  0.792603     0.360328     0.845855  0.223326  ...
# 7      0.115572  0.884428     0.605017     0.919380  0.483585  ...
# 8      0.079374  0.920626     0.726285     0.953380  0.608595  ...
# 9      0.060755  0.939245     0.715311     0.959749  0.607719  ...
# 10     0.210769  0.789230     0.345650     0.839501  0.222578  ...
# 11     0.116864  0.883136     0.595870     0.917610  0.479727  ...
# 12     0.073986  0.926014     0.728361     0.954894  0.609188  ...
# 13     0.061843  0.938157     0.715471     0.959181  0.612297  ...
# 14     0.212136  0.787864     0.344334     0.840925  0.214761  ...
# 15     0.115824  0.884176     0.596032     0.918520  0.478709  ...
# 16     0.078995  0.921005     0.724896     0.952217  0.610417  ...
# 17     0.058679  0.941321     0.730659     0.960254  0.628279  ...
# 18     0.202235  0.797765     0.375276     0.853700  0.228439  ...
# 19     0.113487  0.886513     0.610109     0.921938  0.489060  ...
#
#            Lrec  Lkld      Lcls         Lmix      Lcls_w    Lvae_w    seed  \
# 0   1802.111328   0.0  2.634013          NaN         NaN       NaN  121958
# 1   2131.137207   0.0  2.233664          NaN         NaN       NaN  121958
# 2   3120.419922   0.0  6.633893          NaN         NaN       NaN  121958
# 3   2351.118164   0.0  3.831785  5612.838379  943.036316  0.853218  121958
# 4   1802.925293   0.0  2.624207          NaN         NaN       NaN  121959
# 5   2135.879395   0.0  2.190179          NaN         NaN       NaN  121959
# 6   3125.746094   0.0  6.599988          NaN         NaN       NaN  121959
# 7   2354.849609   0.0  3.807226  5592.862305  943.036316  0.853218  121959
# 8   1808.155273   0.0  2.607471          NaN         NaN       NaN  121960
# 9   2134.367188   0.0  2.272079          NaN         NaN       NaN  121960
# 10  3128.514404   0.0  6.709165          NaN         NaN       NaN  121960
# 11  2356.745361   0.0  3.862321  5646.436523  943.036316  0.853218  121960
# 12  1809.765625   0.0  2.540800          NaN         NaN       NaN  121961
# 13  2155.876221   0.0  2.286009          NaN         NaN       NaN  121961
# 14  3102.327148   0.0  6.711486          NaN         NaN       NaN  121961
# 15  2355.114746   0.0  3.843145  5626.960938  943.036316  0.853218  121961
# 16  1804.880127   0.0  2.600239          NaN         NaN       NaN  121962
# 17  2126.787842   0.0  2.221595          NaN         NaN       NaN  121962
# 18  3104.342773   0.0  6.472734          NaN         NaN       NaN  121962
# 19  2345.193848   0.0  3.766767  5546.469238  943.036316  0.853218  121962
#
#     job_name             version  Group
# 0   kowalski  hek293ft_r2-seed42    OOD
# 1   kowalski  hek293ft_r2-seed42     ID
# 2   kowalski  hek293ft_r2-seed42    OOD
# 3   kowalski  hek293ft_r2-seed42    All
# 4   kowalski  hek293ft_r2-seed42    OOD
# 5   kowalski  hek293ft_r2-seed42     ID
# 6   kowalski  hek293ft_r2-seed42    OOD
# 7   kowalski  hek293ft_r2-seed42    All
# 8   kowalski  hek293ft_r2-seed42    OOD
# 9   kowalski  hek293ft_r2-seed42     ID
# 10  kowalski  hek293ft_r2-seed42    OOD
# 11  kowalski  hek293ft_r2-seed42    All
# 12  kowalski  hek293ft_r2-seed42    OOD
# 13  kowalski  hek293ft_r2-seed42     ID
# 14  kowalski  hek293ft_r2-seed42    OOD
# 15  kowalski  hek293ft_r2-seed42    All
# 16  kowalski  hek293ft_r2-seed42    OOD
# 17  kowalski  hek293ft_r2-seed42     ID
# 18  kowalski  hek293ft_r2-seed42    OOD
# 19  kowalski  hek293ft_r2-seed42    All
#
# [20 rows x 32 columns]

# %%
pp = Pipeline(config_path='config_kolwaski_k562_r1.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
os.makedirs(os.path.join(pp.args.trainer.output_dir, 'anndata'), exist_ok=True)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 23.7 M | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 23.7 M    Trainable params
# 0         Non-trainable params
# 23.7 M    Total params
# 94.965    Total estimated model params size (MB)
# 67        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
