# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '7'
import driver_genes as dg
dg.set_verbosity(False)
from driver_genes.pipelines import Pipeline

# %%
pp = Pipeline(config_path='config_tutorial.yaml')
pp.fit()
pp.save_best_model()
metrics_df, adata_pred = pp.evaluate(num_results=5, concat=True, agg=True)
metrics_df.to_csv(os.path.join(pp.args.trainer.output_dir, 'test_epoch_metrics.csv'), index=False)
os.makedirs(os.path.join(pp.args.trainer.output_dir, 'anndata'), exist_ok=True)
for key in adata_pred.keys():
    adata_pred[key].write(os.path.join(
        pp.args.trainer.output_dir, 
        'anndata', 
        f'{key}.h5ad'
    ))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name               | Type                 | Params | Mode
# --------------------------------------------------------------------
# 0 | model              | DriverGeneFinder     | 5.9 M  | train
# 1 | train_metrics_func | MetricCollection     | 0      | train
# 2 | val_metrics_func   | MetricCollection     | 0      | train
# 3 | test_metrics_func  | MetricCollection     | 0      | train
# 4 | mixing_losses      | UncertaintyWeighting | 3      | train
# --------------------------------------------------------------------
# 5.9 M     Trainable params
# 0         Non-trainable params
# 5.9 M     Total params
# 23.454    Total estimated model params size (MB)
# 68        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
# Testing: |          | 0/? [00:00<?, ?it/s]

# %%
metrics_df
# Out:
#                         prefix  ACC@Top1  ACC@Top5  Coverage       MRR  \
# 0   preprocessed_Re-stimulated  0.913601  0.977383  1.530244  0.940882
# 1         preprocessed_Resting  0.738551  0.922329  2.370949  0.820445
# 2                            a  0.826076  0.949856  1.950596  0.880664
# 3   preprocessed_Re-stimulated  0.922607  0.978843  1.490279  0.947082
# 4         preprocessed_Resting  0.743438  0.926070  2.283787  0.824214
# 5                            a  0.833022  0.952456  1.887033  0.885648
# 6   preprocessed_Re-stimulated  0.924955  0.976537  1.653252  0.946571
# 7         preprocessed_Resting  0.747806  0.928685  2.258843  0.827648
# 8                            a  0.836380  0.952611  1.956047  0.887110
# 9   preprocessed_Re-stimulated  0.925829  0.982614  1.443234  0.949628
# 10        preprocessed_Resting  0.742281  0.926639  2.311150  0.822378
# 11                           a  0.834055  0.954626  1.877192  0.886003
# 12  preprocessed_Re-stimulated  0.926084  0.979413  1.514781  0.948407
# 13        preprocessed_Resting  0.742040  0.926349  2.260721  0.823297
# 14                           a  0.834062  0.952881  1.887751  0.885852
#
#     RankingLoss    RelPos  label#AUPRC  label#AUROC  label#F1  ...  \
# 0      0.007798  0.992202     0.931090     0.992575  0.671699  ...
# 1      0.020161  0.979839     0.887980     0.992171  0.330930  ...
# 2      0.013979  0.986021     0.909535     0.992373  0.501314  ...
# 3      0.007210  0.992790     0.927680     0.992886  0.673094  ...
# 4      0.018879  0.981121     0.885104     0.992378  0.335876  ...
# 5      0.013045  0.986955     0.906392     0.992632  0.504485  ...
# 6      0.009607  0.990393     0.932408     0.990719  0.692786  ...
# 7      0.018512  0.981488     0.879777     0.991289  0.335671  ...
# 8      0.014060  0.985941     0.906093     0.991004  0.514229  ...
# 9      0.006518  0.993482     0.937790     0.993313  0.693248  ...
# 10     0.019282  0.980718     0.878594     0.992180  0.335807  ...
# 11     0.012900  0.987100     0.908192     0.992746  0.514527  ...
# 12     0.007570  0.992430     0.934186     0.992672  0.683330  ...
# 13     0.018540  0.981460     0.888843     0.992839  0.327684  ...
# 14     0.013055  0.986945     0.911514     0.992755  0.505507  ...
#
#           Lrec  Lkld      Lcls         Lmix     Lcls_w    Lvae_w    seed  \
# 0   552.300476   0.0  1.950986          NaN        NaN       NaN  121958
# 1   895.910828   0.0  3.965648          NaN        NaN       NaN  121958
# 2   724.105652   0.0  2.958318  3504.864502  979.30658  0.848616  121958
# 3   551.722717   0.0  1.916384          NaN        NaN       NaN  121959
# 4   899.370300   0.0  3.968001          NaN        NaN       NaN  121959
# 5   725.546448   0.0  2.942193  3490.295898  979.30658  0.848616  121959
# 6   554.828491   0.0  1.874612          NaN        NaN       NaN  121960
# 7   894.080688   0.0  3.931794          NaN        NaN       NaN  121960
# 8   724.454590   0.0  2.903203  3451.186768  979.30658  0.848616  121960
# 9   556.774658   0.0  1.812940          NaN        NaN       NaN  121961
# 10  900.315186   0.0  3.948090          NaN        NaN       NaN  121961
# 11  728.544861   0.0  2.880515  3432.438965  979.30658  0.848616  121961
# 12  554.597717   0.0  1.905621          NaN        NaN       NaN  121962
# 13  896.906006   0.0  3.959345          NaN        NaN       NaN  121962
# 14  725.751831   0.0  2.932483  3480.961182  979.30658  0.848616  121962
#
#             job_name            version  Group
# 0   schmidt_tutorial  stimulated-seed42     ID
# 1   schmidt_tutorial  stimulated-seed42    OOD
# 2   schmidt_tutorial  stimulated-seed42    All
# 3   schmidt_tutorial  stimulated-seed42     ID
# 4   schmidt_tutorial  stimulated-seed42    OOD
# 5   schmidt_tutorial  stimulated-seed42    All
# 6   schmidt_tutorial  stimulated-seed42     ID
# 7   schmidt_tutorial  stimulated-seed42    OOD
# 8   schmidt_tutorial  stimulated-seed42    All
# 9   schmidt_tutorial  stimulated-seed42     ID
# 10  schmidt_tutorial  stimulated-seed42    OOD
# 11  schmidt_tutorial  stimulated-seed42    All
# 12  schmidt_tutorial  stimulated-seed42     ID
# 13  schmidt_tutorial  stimulated-seed42    OOD
# 14  schmidt_tutorial  stimulated-seed42    All
#
# [15 rows x 32 columns]
